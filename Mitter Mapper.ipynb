# %%
import os
# Define local variables
current_directory = os.path.dirname("__file__")
knowledge_directory = os.path.join(current_directory, "knowledge")
db_directory = os.path.join(current_directory, "db")
templates_directory = os.path.join(current_directory, "templates")
group_template = os.path.join(templates_directory, "group.md")

# %%
import glob
from langchain_community.document_loaders import UnstructuredMarkdownLoader

# %%
import os
import glob
from langchain_community.document_loaders import UnstructuredMarkdownLoader

# ✅ Set the actual path to your Markdown files
knowledge_directory = r"C:\Users\youss\Downloads\threat_groups_md"

# Step 1: Locate all Markdown files
group_files = glob.glob(os.path.join(knowledge_directory, "*.md"))

# Step 2: Initialize container
md_docs = []

print("[+] Loading Group markdown files..")

# Step 3: Load each Markdown file
for group_path in group_files:
    if os.path.getsize(group_path) == 0:
        print(f" [!] Skipping empty file: {os.path.basename(group_path)}")
        continue

    try:
        loader = UnstructuredMarkdownLoader(group_path)
        docs = loader.load()
        if docs:
            md_docs.extend(docs)
            print(f" [*] Loaded: {os.path.basename(group_path)} ({len(docs)} docs)")
        else:
            print(f" [!] No content extracted from: {os.path.basename(group_path)}")
    except Exception as e:
        print(f" [!] Error loading {os.path.basename(group_path)}: {e}")

# Step 4: Summary
print(f'[+] Number of .md documents processed: {len(md_docs)}')

# Step 5: Safely preview one of the pages
if len(md_docs) > 5:
    print(md_docs[5].page_content)
elif md_docs:
    print("[i] Fewer than 6 docs found. Showing first one:")
    print(md_docs[0].page_content)
else:
    print("[!] No markdown documents were loaded. Check folder or file format.")
# Out:
# [+] Loading Group markdown files..
# [+] Number of .md documents processed: 0
# [!] No markdown documents were loaded. Check folder or file format.

# %%
from mitreattack.stix20 import MitreAttackData

# Load the enterprise ATT&CK dataset from the STIX 2.0 JSON file
ENTERPRISE_ATTACK_PATH = r"C:\Users\youss\Downloads\enterprise-attack (1).json"

attack_data = MitreAttackData(ENTERPRISE_ATTACK_PATH)

groups = attack_data.get_groups()

for group in groups[:5]:
    print(f"{group['name']} - {group['id']}")
    print(f"Description: {group['description'][:300]}...\n")
# Out:
# Indrik Spider - intrusion-set--01e28736-2ffc-455b-9880-ed4d1407ae07
# Description: [Indrik Spider](https://attack.mitre.org/groups/G0119) is a Russia-based cybercriminal group that has been active since at least 2014. [Indrik Spider](https://attack.mitre.org/groups/G0119) initially started with the [Dridex](https://attack.mitre.org/software/S0384) banking Trojan, and then by 2017 ...
#
# LuminousMoth - intrusion-set--b7f627e2-0817-4cd5-8d50-e75f8aa85cc6
# Description: [LuminousMoth](https://attack.mitre.org/groups/G1014) is a Chinese-speaking cyber espionage group that has been active since at least October 2020. [LuminousMoth](https://attack.mitre.org/groups/G1014) has targeted high-profile organizations, including government entities, in Myanmar, the Philippine...
#
# Wizard Spider - intrusion-set--dd2d9ca6-505b-4860-a604-233685b802c7
# ...

# %%
import os

ENTERPRISE_ATTACK_PATH = r"C:\Users\youss\Downloads\enterprise-attack (2).json"

print("File exists:", os.path.exists(ENTERPRISE_ATTACK_PATH))
# Out:
# File exists: True

# %%
from llama_cpp import Llama
from mitreattack.stix20 import MitreAttackData

# Load the MITRE ATT&CK dataset
ENTERPRISE_ATTACK_PATH = r"C:\Users\youss\Downloads\enterprise-attack (1).json"
attack_data = MitreAttackData(ENTERPRISE_ATTACK_PATH)

# Extract groups
groups = attack_data.get_groups()

# Use description of the first group (or more)
if not groups:
    print("❌ No groups found in the dataset.")
else:
    # Extract text (e.g. from the first group's description)
    text = groups[0]["description"]

    # ✅ Load the LLaMA model
    LLM_MODEL_PATH = r"C:/Users/youss/Downloads/llama-2-7b.Q4_K_M.gguf"
    llm = Llama(model_path=LLM_MODEL_PATH, n_ctx=2048)

    # ✅ Tokenize the text
    tokens = llm.tokenize(text.encode("utf-8"))
    print(f"🧠 Token count: {len(tokens)}")
    print(f"🔢 Tokens: {tokens[:50]}{'...' if len(tokens) > 50 else ''}")
# Out:
# llama_model_loader: loaded meta data with 19 key-value pairs and 291 tensors from C:/Users/youss/Downloads/llama-2-7b.Q4_K_M.gguf (version GGUF V2)
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = LLaMA v2
# llama_model_loader: - kv   2:                       llama.context_length u32              = 4096
# llama_model_loader: - kv   3:                     llama.embedding_length u32              = 4096
# llama_model_loader: - kv   4:                          llama.block_count u32              = 32
# llama_model_loader: - kv   5:                  llama.feed_forward_length u32              = 11008
# llama_model_loader: - kv   6:                 llama.rope.dimension_count u32              = 128
# ...

# %%
# === Step 3: Tokenization Function Using llama-cpp ===
def llama_token_len(text):
    return len(llm.tokenize(text.encode("utf-8")))

# === Step 4: Compute Token Counts (Fix: use .description instead of ["description"]) ===
token_counts = [llama_token_len(group.description) for group in groups if hasattr(group, "description")]

# === Step 5: Print Token Statistics ===
print(f"""[+] Token Counts (Group Descriptions):
Min: {min(token_counts)}  # Minimum tokens
Avg: {int(sum(token_counts) / len(token_counts))}  # Average tokens
Max: {max(token_counts)}  # Maximum tokens
""")
# Out:
# [+] Token Counts (Group Descriptions):
# Min: 47  # Minimum tokens
# Avg: 177  # Average tokens
# Max: 586  # Maximum tokens

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

# Token length function for LLaMA tokenizer
def llama_token_len(text):
    return len(llm.tokenize(text.encode("utf-8")))

# Print a message indicating the initialization of RecursiveCharacterTextSplitter
print('[+] Initializing RecursiveCharacterTextSplitter..')

# Create an instance of RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,           # Max tokens per chunk
    chunk_overlap=50,         # Overlap tokens between chunks
    length_function=llama_token_len,  # Use LLaMA-based token count
    separators=['\n\n', '\n', ' ', '']  # Hierarchical splitting rules
)
# Out:
# [+] Initializing RecursiveCharacterTextSplitter..

# %%
group_texts = [group.description for group in groups if hasattr(group, 'description')]
chunks = text_splitter.create_documents(group_texts)
print(f"[+] Created {len(chunks)} chunks.")
# Out:
# [+] Created 194 chunks.

# %%
print(chunks[1])
# Out:
# page_content='[LuminousMoth](https://attack.mitre.org/groups/G1014) is a Chinese-speaking cyber espionage group that has been active since at least October 2020. [LuminousMoth](https://attack.mitre.org/groups/G1014) has targeted high-profile organizations, including government entities, in Myanmar, the Philippines, Thailand, and other parts of Southeast Asia. Some security researchers have concluded there is a connection between [LuminousMoth](https://attack.mitre.org/groups/G1014) and [Mustang Panda](https://attack.mitre.org/groups/G0129) based on similar targeting and TTPs, as well as network infrastructure overlaps.(Citation: Kaspersky LuminousMoth July 2021)(Citation: Bitdefender LuminousMoth July 2021)'

# %%
from sentence_transformers import SentenceTransformer
from langchain.vectorstores import FAISS
from langchain.embeddings import HuggingFaceEmbeddings

# Load a local embedding model
print("[+] Loading local embedding model...")
embedding_model = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

# Embed and store in FAISS
print("[+] Creating vector store with FAISS...")
db = FAISS.from_documents(chunks, embedding_model)
# Out:
# [+] Loading local embedding model...
# [+] Creating vector store with FAISS...

# %%
retriever = db.as_retriever(search_kwargs={"k":5})

# %%
query =  "Who is Lazarus?"

# %%
print("[+] Getting relevant documents for query..")
relevant_docs = retriever.get_relevant_documents(query)
relevant_docs
# Out:
# [+] Getting relevant documents for query..
# ...

# %%
from ipywidgets import interact_manual, Layout, widgets 
from langchain.chains.qa_with_sources import load_qa_with_sources_chain
from langchain.chains import RetrievalQA
from langchain.llms import HuggingFacePipeline  # or your specific LLaMA wrapper
from langchain_community.llms import LlamaCpp

llm = LlamaCpp(
    model_path=LLM_MODEL_PATH,
    temperature=0.3,
    max_tokens=512,
    top_p=0.95,
    n_ctx=2048,
    verbose=True
)

# Set the layout of the text box
text_layout = Layout(width='80%', height='50px')

# Example LLaMA model loading (you should replace this with your actual LLaMA pipeline/model)
# llm = HuggingFacePipeline(pipeline=your_pipeline)

# Use FAISS retriever
retriever = db.as_retriever(search_kwargs={"k": 3})

# Define the query execution function
def execute_query(query):
    print(f"Your query: {query}")
    print("[+] Retrieving relevant documents...")
    relevant_docs = retriever.get_relevant_documents(query)

    print("[+] Running LLaMA model on retrieved documents...")
    
    # Correct usage — you can use RetrievalQA or load_qa_with_sources_chain
    qa_chain = RetrievalQA.from_chain_type(llm=llm, retriever=retriever, chain_type="stuff")
    result = qa_chain.run(query)

    print("\n[+] Answer:")
    print(result)

# Create interactive widget
interact_manual(
    execute_query,
    query=widgets.Text(
        value='',
        placeholder='Ask about a MITRE technique or group...',
        description='Query:',
        layout=text_layout
    )
)
# Out:
# llama_model_loader: loaded meta data with 19 key-value pairs and 291 tensors from C:/Users/youss/Downloads/llama-2-7b.Q4_K_M.gguf (version GGUF V2)
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = LLaMA v2
# llama_model_loader: - kv   2:                       llama.context_length u32              = 4096
# llama_model_loader: - kv   3:                     llama.embedding_length u32              = 4096
# llama_model_loader: - kv   4:                          llama.block_count u32              = 32
# llama_model_loader: - kv   5:                  llama.feed_forward_length u32              = 11008
# llama_model_loader: - kv   6:                 llama.rope.dimension_count u32              = 128
# ...

# %%
from langchain.llms import LlamaCpp

# instead of llama_cpp.llama.Llama(...)
llm = LlamaCpp(model_path=LLM_MODEL_PATH)
# Out:
# llama_model_loader: loaded meta data with 19 key-value pairs and 291 tensors from C:/Users/youss/Downloads/llama-2-7b.Q4_K_M.gguf (version GGUF V2)
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = LLaMA v2
# llama_model_loader: - kv   2:                       llama.context_length u32              = 4096
# llama_model_loader: - kv   3:                     llama.embedding_length u32              = 4096
# llama_model_loader: - kv   4:                          llama.block_count u32              = 32
# llama_model_loader: - kv   5:                  llama.feed_forward_length u32              = 11008
# llama_model_loader: - kv   6:                 llama.rope.dimension_count u32              = 128
# ...

# %%
from langchain.chains.question_answering import load_qa_chain
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate
from langchain.llms import LlamaCpp

# 1. Wrap your model in LangChain’s LlamaCpp
llm = LlamaCpp(model_path=LLM_MODEL_PATH)

# 2. Build your custom prompt
custom_prompt = PromptTemplate.from_template("""
You are a cybersecurity expert helping with MITRE ATT&CK investigations.
Use the following context to answer the question.
If you don’t know the answer, respond with "I am sorry".

Context:
{context}

Question: {question}
Answer:
""")

# 3. Load the “stuff” chain with that Runnable LLM
qa_chain = load_qa_chain(
    llm=llm,
    chain_type="stuff",
    prompt=custom_prompt
)

# 4. Wrap it in RetrievalQA
retrieval_qa = RetrievalQA(
    retriever=retriever,
    combine_documents_chain=qa_chain,
    return_source_documents=False
)

# 5. Run
def execute_query(question):
    print(f"User: {question}")
    answer = retrieval_qa.run(question)
    print(f"Bot: {answer}")
# Out:
# llama_model_loader: loaded meta data with 19 key-value pairs and 291 tensors from C:/Users/youss/Downloads/llama-2-7b.Q4_K_M.gguf (version GGUF V2)
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = LLaMA v2
# llama_model_loader: - kv   2:                       llama.context_length u32              = 4096
# llama_model_loader: - kv   3:                     llama.embedding_length u32              = 4096
# llama_model_loader: - kv   4:                          llama.block_count u32              = 32
# llama_model_loader: - kv   5:                  llama.feed_forward_length u32              = 11008
# llama_model_loader: - kv   6:                 llama.rope.dimension_count u32              = 128
# ...

# %%
from langchain.chains import RetrievalQA
qa_chain = load_qa_chain(
    llm=llm,
    chain_type="stuff",
    prompt=custom_prompt
)
retrieval_qa = RetrievalQA.from_chain_type(
    llm=llm,
    retriever=retriever,
    chain_type="map_reduce",             # ← change here
    chain_type_kwargs={
        "prompt": custom_prompt,         # your same custom prompt
        "reduce_prompt": custom_prompt,  # or a simpler merge prompt
        "chunk_size": 1000,              # tokens per chunk
    },
    return_source_documents=False
)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[52], line 7
#       1 from langchain.chains import RetrievalQA
#       2 qa_chain = load_qa_chain(
#       3     llm=llm,
#       4     chain_type="stuff",
#       5     prompt=custom_prompt
#       6 )
# ----> 7 retrieval_qa = RetrievalQA.from_chain_type(
#       8     llm=llm,
#       9     retriever=retriever,
#      10     chain_type="map_reduce",             # ← change here
#      11     chain_type_kwargs={
#      12         "prompt": custom_prompt,         # your same custom prompt
#      13         "reduce_prompt": custom_prompt,  # or a simpler merge prompt
#      14         "chunk_size": 1000,              # tokens per chunk
#      15     },
#      16     return_source_documents=False
#      17 )
#
# ...
